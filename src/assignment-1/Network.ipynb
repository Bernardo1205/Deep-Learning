# %% [markdown]
# # Assignment 1: First NN (Refactor)

# %%
from main import run_training_pipeline
from evaluate import run_evaluation
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400         0           1                 0
# 1   18  33.770         1   1725.55230         1           0                 0
# 2   28  33.000         3   4449.46200         1           0                 0
# 3   33  22.705         0  21984.47061         1           0                 1
# 4   32  28.880         0   3866.85520         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
artifacts_path = run_training_pipeline(
    csv_path="dataset/insurance.csv",
    model_path="artifacts/model_artifacts.pth",
    n_trials=30,
    epochs=50
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 artifacts_path = run_training_pipeline(
#       2     csv_path="dataset/insurance.csv",
#       3     model_path="artifacts/model_artifacts.pt",
#       4     n_trials=30,
#       5     epochs=50
#       6 )
#
# NameError: name 'run_training_pipeline' is not defined

# %%
run_evaluation(model_path=artifacts_path, csv_path="dataset/insurance.csv", n_examples=10)
